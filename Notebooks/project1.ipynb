# %%
# VIABILITY OF THE INDIAN ECONOMY FOR START_UP BUSINESSES , A FUNDIND ANALYSIS - 2018-2021

# %% [markdown]
# BUSINESS UNDERSTANDING

# %% [markdown]
# BACKGROUND : India has emerged as one of the most dynamic startup ecosystem attracting significant investment and fostering innovation accross various sectors. As our team plans to venture into this market, it is crucial to understand the key trends , investor patterns and sector specific insights to make informed strategic decisions.
#
#
# KEY OBJECTIVE OF THE PROJECT : The main objective is to comprehensively analyze the Indian Startup Ecosystem from 2018 to 2021, identify key trends and insights and provide data driven recommendations for strategic entry and investment opportunities in the indian economy for  startup businesses.
#
#
# Hypothesis
#
# Null Hypothesis(H0):
# There is no signficant difference in the average funding amounts received across different sectors within the Indian startup ecosystem from 2018 to 2021.
#
# Alternative Hypothesis(H1):
# There is a significant difference in the average funding amounts received across different sectors within the Indian startup ecosystem from 2018 to 2021
#
# Key Research Questions
# 1. How has the total amount of funding received by start-ups in India changed from 2018-2021?
# 2. Which sectors have received the most funding in each year?
# 3. Who are the top investors in the India start-up ecosystem from 2018-2021?
# 4. Which regions or cities in India are receiving the most start-up funding?
# 5. Does the stage align with the investment timeline?
# 6. How long has the company been operating and how doeas this affect the amount of investment?

# %% [markdown]
# DATA UNDERSTANDING

# %%
import pandas as pd

# %%
from dotenv import dotenv_values  #import dotenv_values package from dotenv
import pandas as pd
import warnings
import pyodbc
warnings.filterwarnings('ignore')

# %% [markdown]
# server="dap-projects-database.database.windows.net"
# Login="LP1_learner"
# password="Hyp0th3s!$T3$t!ng"
# database="dapDB"

# %%
environment_variables = dotenv_values('.env')
# Get the values for the credentials you aet in the '.env' file
database = environment_variables.get("database")
server = environment_variables.get("server")
login = environment_variables.get("Login")
password = environment_variables.get("password")
database = environment_variables.get("database")

connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={login};PWD={password}"

# %%
connection = pyodbc.connect(connection_string)

# What tables are in the DB
db_query = '''SELECT *
FROM INFORMATION_SCHEMA.TABLES
WHERE TABLE_TYPE = 'BASE TABLE' '''

# %%
db_query = ''' SELECT * FROM dbo.LP1_startup_funding2020'''

data_2020 = pd.read_sql(db_query, connection)
data_2020.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.5+ KB

# %%
data_2020.shape
# Out:
# (1055, 10)

# %%
db_query = ''' SELECT * FROM dbo.LP1_startup_funding2021'''

data_2021 = pd.read_sql(db_query, connection)
data_2021.head()
# Out:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# ...

# %%
data_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %%
data_2021.shape
# Out:
# (1209, 9)

# %%
data_2019 = pd.read_csv(r"C://Users//GAMING//Desktop//DATA ANALYTICS//AZUBI AFRICA- Data Analytics//CARREER ACELERATOR//PROJECT 1//startup_funding2019.csv")

data_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
# ...

# %%
data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
data_2019.shape
# Out:
# (89, 9)

# %%
data_2018 = pd.read_csv(r"C:\Users\GAMING\Desktop\DATA ANALYTICS\AZUBI AFRICA- Data Analytics\CARREER ACELERATOR\PROJECT 1\startup_funding2018.csv")

data_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# ...

# %%
data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
data_2018.shape
# Out:
# (526, 6)

# %%
# Data Manipulation

# %%
# Renaming Columns for Consistency

# %%
# Rename Columns for 2020 and 2021 datasets

data_2020.rename(columns={
    'Company_Brand' : 'Company',
    'What_it_does' : 'What it does',
    'Amount' : 'Amount($)'
    }, inplace=True)

data_2021.rename(columns={
    'Company_Brand' : 'Company',
    'What_it_does' : 'What it does',
    'Amount' : 'Amount($)'
}, inplace=True)

# %%
data_2021.columns
# Out:
# Index(['Company', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage'],
#       dtype='object')

# %%
data_2020.columns
# Out:
# Index(['Company', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage', 'column10'],
#       dtype='object')

# %%
# Renmme columsn for 2018 and 2019n datasets

data_2018.rename(columns={
    'Company Name' : 'Company',
    'Industry' : 'Sector',
    'Round/Series' : 'Stage',
    'Amount' : 'Amount($)',
    'Location' : 'HeadQuarter',
    'About Company' : 'What it does'
}, inplace=True)

data_2019.rename(columns={
    'Company/Brand' : 'Company'
}, inplace=True)

# %%
data_2019.columns
# Out:
# Index(['Company', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage', 'year'],
#       dtype='object')

# %%
data_2018.head()
# Out:
#            Company                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#       Stage    Amount($)                       HeadQuarter  \
# 0      Seed       250000       Bangalore, Karnataka, India
# 1      Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2  Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3     Angel      2000000       Noida, Uttar Pradesh, India
# 4      Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                         What it does
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# ...

# %%
data_2018.columns
# Out:
# Index(['Company', 'Sector', 'Stage', 'Amount($)', 'HeadQuarter',
#        'What it does'],
#       dtype='object')

# %%
# Convert 2020 and 2021 dataframes into csv file formant for standardization

# %%
# Convert the Dataframes into CSV files
data_2020.to_csv('df_2020.csv', index=False)
data_2021.to_csv('df_2021.csv', index=False)

# %%
# Read the CSV files
data_2018 = pd.read_csv(r'C:\Users\GAMING\Desktop\DATA ANALYTICS\AZUBI AFRICA- Data Analytics\CARREER ACELERATOR\PROJECT 1\startup_funding2018.csv')
data_2019 = pd.read_csv(r'C:\Users\GAMING\Desktop\DATA ANALYTICS\AZUBI AFRICA- Data Analytics\CARREER ACELERATOR\PROJECT 1\startup_funding2019.csv')
data_2020 = pd.read_csv('df_2020.csv')
data_2021 = pd.read_csv('df_2021.csv')

# %%
# Add the 'year' column to each Dataframe

data_2018['year'] = 2018
data_2019['year'] = 2019
data_2020['year'] = 2020
data_2021['year'] = 2021

# Convert the DataFrames to CSV fils

data_2018.to_csv('df_2018_with_year.csv', index=False)
data_2019.to_csv('df_2019_with_year.csv', index=False)
data_2020.to_csv('df_2020_with_year.csv', index=False)
data_2021.to_csv('df_2021_with_year.csv', index=False)

# %%
# Define a fixed conversion rate for INR  to USD 
INR_TO_USD = 0.015


def convert_amount(amount):
    # Ensure that amount is all string as the replace function does not apply on float objects 

    # Check if the amount is already a float. If it is return it as it is.
    if isinstance(amount, float):
        return amount
    
    # Proceed to with amounts in string  form in order to apply replace function

    # Ensure the amount is a string and remove commas and whitespace
    amount_str = str(amount).replace(',', '').strip()
    
    try:
        # Check if the string starts with $ or ₹
        if amount_str.startswith('$'):
            return float(amount_str.replace('$', ''))
        elif amount_str.startswith('₹'):
            # Convert INR to USD using the fixed rate
            amount_inr = float(amount_str.replace('₹', ''))
            amount_usd = amount_inr * INR_TO_USD
            return amount_usd
        else:
            # Handle scientific notation and plain numbers
            return float(amount_str)
    except ValueError:
        # Handle any conversion errors (e.g., malformed strings)
        return None

# %%
data_2018.head()
# Out:
#            Company                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#       Stage    Amount($)                       HeadQuarter  \
# 0      Seed       250000       Bangalore, Karnataka, India
# 1      Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2  Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3     Angel      2000000       Noida, Uttar Pradesh, India
# 4      Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                         What it does  year
# 0  TheCollegeFever is a hub for fun, fiesta and f...  2018
# 1  A startup which aggregates milk from dairy far...  2018
# ...

# %%
# Applying conversion amounts

# Apply conversion to the 'Amount($)' column for all datasets
data_2018['Amount($)'] = data_2018['Amount($)'].apply(convert_amount)
data_2019['Amount($)'] = data_2019['Amount($)'].apply(convert_amount)
data_2020['Amount($)'] = data_2020['Amount($)'].apply(convert_amount)
data_2021['Amount($)'] = data_2021['Amount($)'].apply(convert_amount)

# %%
# Concatenate the datasets

final_data = pd.concat([data_2021, data_2020, data_2019, data_2018],ignore_index=True)

# Save the Fina_data as a csv file
final_data.to_csv('final_data_with_year.csv', index=False)

# %%
final_data.columns
# Out:
# Index(['Company', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage', 'year', 'column10'],
#       dtype='object')

# %%
final_data.head()
# Out:
#           Company  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# ...

# %%
final_data.tail()
# Out:
#                 Company  Founded                  HeadQuarter  \
# 2874              Udaan      NaN  Bangalore, Karnataka, India
# 2875  Happyeasygo Group      NaN      Haryana, Haryana, India
# 2876             Mombay      NaN   Mumbai, Maharashtra, India
# 2877         Droni Tech      NaN   Mumbai, Maharashtra, India
# 2878            Netmeds      NaN   Chennai, Tamil Nadu, India
#
#                                                 Sector  \
# 2874  B2B, Business Development, Internet, Marketplace
# 2875                                   Tourism, Travel
# 2876        Food and Beverage, Food Delivery, Internet
# 2877                            Information Technology
# 2878        Biotechnology, Health Care, Pharmaceutical
#
#                                            What it does Founders Investor  \
# 2874  Udaan is a B2B trade platform, designed specif...      NaN      NaN
# 2875            HappyEasyGo is an online travel domain.      NaN      NaN
# ...

# %%
# Exploratory Data Analysis

# %%
# Determining the shape of the final_data

final_data.shape
# Out:
# (2879, 11)

# %%
# Determining the null values

final_data.isna().any()
# Out:
# Company         False
# Founded          True
# HeadQuarter      True
# Sector           True
# What it does    False
# Founders         True
# Investor         True
# Amount($)        True
# Stage            True
# year            False
# column10         True
# dtype: bool

# %%
# Determining the null values

final_data.isna().sum()
# Out:
# Company            0
# Founded          769
# HeadQuarter      114
# Sector            18
# What it does       0
# Founders         545
# Investor         626
# Amount($)        567
# Stage            938
# year               0
# column10        2877
# dtype: int64

# %%
# Assessing the columns in the final_data set

final_data.columns
# Out:
# Index(['Company', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage', 'year', 'column10'],
#       dtype='object')

# %%
# General overview of the data

final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2879 entries, 0 to 2878
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       2879 non-null   object
#  1   Founded       2110 non-null   float64
#  2   HeadQuarter   2765 non-null   object
#  3   Sector        2861 non-null   object
#  4   What it does  2879 non-null   object
#  5   Founders      2334 non-null   object
#  6   Investor      2253 non-null   object
#  7   Amount($)     2312 non-null   float64
#  8   Stage         1941 non-null   object
#  9   year          2879 non-null   int64
#  10  column10      2 non-null      object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 247.5+ KB

# %%
# Determining datatyoes

final_data.dtypes
# Out:
# Company          object
# Founded         float64
# HeadQuarter      object
# Sector           object
# What it does     object
# Founders         object
# Investor         object
# Amount($)       float64
# Stage            object
# year              int64
# column10         object
# dtype: object

# %%
# Gainning insights into the descriptive statitstics of the entire data

final_data.describe(include='all').T
# Out:
#                count unique                               top freq  \
# Company         2879   2214                          BharatPe   10
# Founded       2110.0    NaN                               NaN  NaN
# HeadQuarter     2765    172                         Bangalore  764
# Sector          2861    873                           FinTech  173
# What it does    2879   2691  Provides online learning classes    5
# Founders        2334   1980  Ashneer Grover, Shashvat Nakrani    7
# Investor        2253   1777         Inflection Point Ventures   36
# Amount($)     2312.0    NaN                               NaN  NaN
# Stage           1941     75                              Seed  606
# year          2879.0    NaN                               NaN  NaN
# column10           2      2                          Pre-Seed    1
#
#                          mean                std     min        25%  \
# Company                   NaN                NaN     NaN        NaN
# ...

# %%
final_data.describe().T
# Out:
#             count          mean           std     min        25%        50%  \
# Founded    2110.0  2.016080e+03  4.368006e+00  1963.0     2015.0     2017.0
# Amount($)  2312.0  1.212686e+08  3.442955e+09   900.0  1000000.0  3000000.0
# year       2879.0  2.020024e+03  1.086974e+00  2018.0     2020.0     2020.0
#
#                   75%           max
# Founded        2019.0  2.021000e+03
# Amount($)  12000000.0  1.500000e+11
# year           2021.0  2.021000e+03

# %%
final_data.describe(include=['object']).T
# Out:
#              count unique                               top freq
# Company       2879   2214                          BharatPe   10
# HeadQuarter   2765    172                         Bangalore  764
# Sector        2861    873                           FinTech  173
# What it does  2879   2691  Provides online learning classes    5
# Founders      2334   1980  Ashneer Grover, Shashvat Nakrani    7
# Investor      2253   1777         Inflection Point Ventures   36
# Stage         1941     75                              Seed  606
# column10         2      2                          Pre-Seed    1

# %%
# Determoining unique values

final_data.nunique()
# Out:
# Company         2214
# Founded           34
# HeadQuarter      172
# Sector           873
# What it does    2691
# Founders        1980
# Investor        1777
# Amount($)        471
# Stage             75
# year               4
# column10           2
# dtype: int64

# %% [markdown]
# Data Cleaning

# %% [markdown]
# Handling Missing Values

# %%
final_data.isnull().sum()
# Out:
# Company            0
# Founded          769
# HeadQuarter      114
# Sector            18
# What it does       0
# Founders         545
# Investor         626
# Amount($)        567
# Stage            938
# year               0
# column10        2877
# dtype: int64

# %%
# Drop unessential columns

final_data.drop(['column10'], axis = 1, inplace = True)

# %%
final_data.columns
# Out:
# Index(['Company', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage', 'year'],
#       dtype='object')

# %% [markdown]
# HeadQuarter Column

# %%
HeadQuarter = final_data['HeadQuarter']

print(HeadQuarter)
# Out:
# 0                         Bangalore
# 1                            Mumbai
# 2                            Mumbai
# 3                            Mumbai
# 4                          Gurugram
#                    ...
# 2874    Bangalore, Karnataka, India
# 2875        Haryana, Haryana, India
# 2876     Mumbai, Maharashtra, India
# 2877     Mumbai, Maharashtra, India
# 2878     Chennai, Tamil Nadu, India
# Name: HeadQuarter, Length: 2879, dtype: object

# %%
# Assuming 'Company' and 'Head Quarter' are separate columns in your DataFrame
# Iterating over both 'Company' and 'Head Quarter' columns

for index, row in final_data.iterrows():
    company = row['Company']
    head_quarter = row['HeadQuarter']
    print(f"Index: {index}, Company: {company}, HeadQuarter: {head_quarter}")
# Out:
# Index: 0, Company: Unbox Robotics, HeadQuarter: Bangalore
# Index: 1, Company: upGrad, HeadQuarter: Mumbai
# Index: 2, Company: Lead School, HeadQuarter: Mumbai
# Index: 3, Company: Bizongo, HeadQuarter: Mumbai
# Index: 4, Company: FypMoney, HeadQuarter: Gurugram
# Index: 5, Company: Urban Company, HeadQuarter: New Delhi
# Index: 6, Company: Comofi Medtech, HeadQuarter: Bangalore
# Index: 7, Company: Qube Health, HeadQuarter: Mumbai
# Index: 8, Company: Vitra.ai, HeadQuarter: Bangalore
# Index: 9, Company: Taikee, HeadQuarter: Mumbai
# Index: 10, Company: Fitterfly, HeadQuarter: Mumbai
# Index: 11, Company: FreeStand, HeadQuarter: New Delhi
# Index: 12, Company: MyDentalPlan, HeadQuarter: Bangalore
# Index: 13, Company: Freyr Energy, HeadQuarter: Hyderabad
# Index: 14, Company: DealShare, HeadQuarter: Jaipur
# Index: 15, Company: Tessolve, HeadQuarter: Bangalore
# Index: 16, Company: Smart Joules, HeadQuarter: New Delhi
# Index: 17, Company: ORAI, HeadQuarter: Bangalore
# ...

# %%
# Fill missing values in the 'HeadQuarter' column using manual imputation

final_data.at[29,'HeadQuarter'] = 'New Delhi'
final_data.at[32,'HeadQuarter'] = 'Andhra Pradesh'
final_data.at[43,'HeadQuarter'] = 'Faridabad'
final_data.at[98,'HeadQuarter'] = 'Bengaluru'
final_data.at[111,'HeadQuarter'] = 'Bengaluru'
final_data.at[241,'HeadQuarter'] = 'New Delhi'
final_data.at[242,'HeadQuarter'] = 'Mumbai'
final_data.at[255,'HeadQuarter'] = 'New Delhi'
final_data.at[256,'HeadQuarter'] = 'Mumbai'
final_data.at[257,'HeadQuarter'] = 'Gurugram'
final_data.at[806,'HeadQuarter'] = 'Faridabad'
final_data.at[1100,'HeadQuarter'] = 'Bangalore'
final_data.at[1176,'HeadQuarter'] = 'Manchester'
final_data.at[1287,'HeadQuarter'] = 'Tirunelveli'
final_data.at[1370,'HeadQuarter'] = 'Jaipur'
final_data.at[1375,'HeadQuarter'] = 'Frisco'
final_data.at[1393,'HeadQuarter'] = 'Dhingsara'
final_data.at[1395,'HeadQuarter'] = 'New York'
final_data.at[1400,'HeadQuarter'] = 'Jaipur'
final_data.at[1407,'HeadQuarter'] = 'Jaipur'
final_data.at[1432,'HeadQuarter'] = 'San Francisco'
final_data.at[1434,'HeadQuarter'] = 'San Francisco'
final_data.at[1438,'HeadQuarter'] = 'San Ramon'
final_data.at[1439,'HeadQuarter'] = 'Paris'
final_data.at[1441,'HeadQuarter'] = 'Texas'
final_data.at[1449,'HeadQuarter'] = 'San Francisco'
final_data.at[1469,'HeadQuarter'] = 'London'
final_data.at[1470,'HeadQuarter'] = 'Sydney'
final_data.at[1471,'HeadQuarter'] = 'Milano'
final_data.at[1473,'HeadQuarter'] = 'New York'
final_data.at[1474,'HeadQuarter'] = 'Queensland'
final_data.at[1482,'HeadQuarter'] = 'London'
final_data.at[1488,'HeadQuarter'] = 'San Francisco'
final_data.at[1491,'HeadQuarter'] = 'Trivandrum'
final_data.at[2307,'HeadQuarter'] = 'Bengaluru'
final_data.at[2318,'HeadQuarter'] = 'Gurugram'
final_data.at[2329,'HeadQuarter'] = 'New Delhi'
final_data.at[2334,'HeadQuarter'] = 'Chennai'
final_data.at[2340,'HeadQuarter'] = 'Bengaluru'
final_data.at[2343,'HeadQuarter'] = 'Bangalore'
final_data.at[2365,'HeadQuarter'] = 'Atlanta'
final_data.at[2395,'HeadQuarter'] = 'Faridabad'
final_data.at[2412,'HeadQuarter'] = 'New Delhi'
final_data.at[2552,'HeadQuarter'] = 'Noida'
final_data.at[2]

# %%
# Checking to confirmn the repalcement of the missing values in the HeadQuarter column

final_data.isnull().sum()
# Out:
# Company           0
# Founded         769
# HeadQuarter       7
# Sector           18
# What it does      0
# Founders        545
# Investor        626
# Amount($)       567
# Stage           938
# year              0
# dtype: int64

# %%
# Get the details of remaining rows with missing values in the HeadQuarter column

missing_values = final_data[final_data['HeadQuarter'].isnull()].index

print("indices with missing values:", missing_values)
# Out:
# indices with missing values: Index([1296, 1301, 1304, 1330, 2132, 2222, 2284], dtype='int64')

# %%
# Fill missing values in the 'HeadQuarter' column using manual imputation

final_data.at[1296, 'HeadQuarter'] = 'Mumbai'
final_data.at[1301, 'HeadQuarter'] = 'Noida'
final_data.at[1304, 'HeadQuarter'] = 'Delhi'
final_data.at[1330, 'HeadQuarter'] = 'Pune'
final_data.at[2132, 'HeadQuarter'] = 'Mumbai'
final_data.at[2222, 'HeadQuarter'] = 'Gurgaon'
final_data.at[2284, 'HeadQuarter'] = 'New Delhi'

# %%
# Checking to confirmn the repalcement of the missing values in the HeadQuarter column

final_data.isnull().sum()
# Out:
# Company           0
# Founded         769
# HeadQuarter       0
# Sector           18
# What it does      0
# Founders        545
# Investor        626
# Amount($)       567
# Stage           938
# year              0
# dtype: int64

# %% [markdown]
# Stage Column

# %%
final_data['Stage'].unique()
# Out:
# array(['Pre-series A', nan, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        '$1200000', 'Bridge', 'Seed+', 'Series F2', 'Series A+',
#        'Series G', 'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', '$300000', 'Early seed', 'Series D1', '$6000000',
#        '$1000000', 'Seies A', 'Pre-series', 'Series A2', 'Series I',
#        'Pre-series C', 'Series B2', 'Pre- series A', 'Edge',
#        'Pre-Series B', 'Seed A', 'Series A-1', 'Seed Funding', 'Pre-Seed',
#        'Seed round', 'Pre-seed Round', 'Seed Round & Series A',
#        'Pre Series A', 'Pre seed Round', 'Angel Round', 'Pre series A1',
#        'Series E2', 'Pre series A', 'Seed Round', 'Bridge Round',
#        'Pre seed round', 'Pre series B', 'Pre series C',
#        'Seed Investment', 'Mid series', 'Series C, D', 'Seed funding',
#        'Fresh funding', 'Post series A', 'Seed fund', 'Series B+',
# ...

# %%
# Fill missing values in the 'Stage' column using forward fill and backward fill

final_data['Stage'] = final_data['Stage'].fillna(method='ffill').fillna(method='bfill')

# %%
final_data['Stage'].unique()
# Out:
# array(['Pre-series A', 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        '$1200000', 'Bridge', 'Seed+', 'Series F2', 'Series A+',
#        'Series G', 'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', '$300000', 'Early seed', 'Series D1', '$6000000',
#        '$1000000', 'Seies A', 'Pre-series', 'Series A2', 'Series I',
#        'Pre-series C', 'Series B2', 'Pre- series A', 'Edge',
#        'Pre-Series B', 'Seed A', 'Series A-1', 'Seed Funding', 'Pre-Seed',
#        'Seed round', 'Pre-seed Round', 'Seed Round & Series A',
#        'Pre Series A', 'Pre seed Round', 'Angel Round', 'Pre series A1',
#        'Series E2', 'Pre series A', 'Seed Round', 'Bridge Round',
#        'Pre seed round', 'Pre series B', 'Pre series C',
#        'Seed Investment', 'Mid series', 'Series C, D', 'Seed funding',
#        'Fresh funding', 'Post series A', 'Seed fund', 'Series B+',
# ...

# %%
# Define the mapping dictionary
stage_mapping = {
    'Pre-Series A': ['Pre-Series A', 'Pre Series A', 'Pre series A1', 'Series A2'],
    'Pre-Series B': ['Pre-Series B', 'Pre Series B'],
    'Series B': ['Series B', 'Series B3', 'Series B+', 'Series B2', 'Venture - Series Unknown', 'Debt'],
    'Series A': ['Series A+', 'Series A-1', 'Series A', 'Seed Round & Series A', 'Pre-series A1'],
    'Series F': ['Series F', 'Series F2', 'Series F1'],
    'Seed': ['Seed Investment', 'Seed Funding', 'Seed funding', 'Seed+', 'Pre-seed Round'],
    'Series E': ['Series E', 'Series E2'],
    'Pre-Series C': ['Pre-Series C', 'Pre Series C'],
    'Series C' : ['Series C, D'],
    'Series D': ['Series D1']
}

# Invert the mapping dictionary to map individual variations to their standard stage names
inverted_mapping = {v: k for k, values in stage_mapping.items() for v in values}

# Apply the mapping to the 'stage' column permanently
final_data['Stage'] = final_data['Stage'].replace(inverted_mapping)

# Display the updated DataFrame to verify the changes
print(final_data['Stage'].unique())
# Out:
# ['Pre-series A' 'Series D' 'Series C' 'Seed' 'Series B' 'Series E'
#  'Pre-seed' 'Series A' 'Pre-series B' '$1200000' 'Bridge' 'Series F'
#  'Series G' 'Series H' 'PE' '$300000' 'Early seed' '$6000000' '$1000000'
#  'Seies A' 'Pre-series' 'Pre-Series A' 'Series I' 'Pre-series C'
#  'Pre- series A' 'Edge' 'Pre-Series B' 'Seed A' 'Pre-Seed' 'Seed round'
#  'Pre seed Round' 'Angel Round' 'Pre series A' 'Seed Round' 'Bridge Round'
#  'Pre seed round' 'Pre series B' 'Pre series C' 'Mid series'
#  'Fresh funding' 'Post series A' 'Seed fund' 'Angel' 'Private Equity'
#  'Grant' 'Debt Financing' 'Post-IPO Debt' 'Corporate Round' 'Undisclosed'
#  'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593'
#  'Secondary Market' 'Post-IPO Equity' 'Non-equity Assistance'
#  'Funding Round']

# %%
final_data.isnull().sum()
# Out:
# Company           0
# Founded         769
# HeadQuarter       0
# Sector           18
# What it does      0
# Founders        545
# Investor        626
# Amount($)       567
# Stage             0
# year              0
# dtype: int64
